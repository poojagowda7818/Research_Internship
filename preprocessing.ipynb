# %%
import pandas as pd

data = pd.read_csv('manifest2.csv')

# %%
df = (data[data['video_source']=='minnesota'])
df
# Out:
#                                 video_uid  \
# 0    77cc4654-4eec-44c6-af05-dbdf71f9a401
# 12   f7148e30-2ded-4d14-a8bb-f50813da26df
# 20   2cddb76f-24d1-4863-bd91-9a5d1922a543
# 29   e3ee87c2-0e48-49cd-93e3-1e39e61a8543
# 34   0235dafb-ec68-4177-8aff-e36d6c63742d
# 40   a8238ec0-a8d8-4b2e-8d92-d161bb6dcdca
# 46   ba01d474-f7dd-48f1-863d-80dcf1a60ea4
# 47   e4475271-ea33-4f82-9768-355b226c50ca
# 53   a95545b6-8b1e-4d77-a209-c1accf3b057b
# 65   f05e4680-0ef5-453e-a096-4f9318df00ae
# 71   343f8d57-6331-40f3-823c-2aee4d5cc10f
# 78   95673c4c-9c12-4eba-949b-9bd7a29d299d
# 80   86ebad37-486c-4687-b50e-67627a4be7a2
# 88   f3c90baa-1154-4d30-bdee-f94d1b834f3e
# 91   806ebea9-a28f-4429-821c-1e8a753b7ab7
# 101  b849a2d6-3eff-4c64-aded-2d706ed1091e
# 104  8be6e0c4-a80d-41a3-a1c5-5911ae236990
# 105  b2625bd9-4ce6-4f5a-bf87-030c779c9d5a
# 121  96267fe7-19c1-4409-b333-4fa08c27c38e
# 134  1c663b98-e28a-4036-b66e-17d942902d32
# 139  1e1e7831-098c-4d1b-b68b-943a693b87a7
# ...

# %%
df.to_csv('minnesota.csv')

# %%
df2 = pd.read_csv('minnesota.csv')

# %%
df2
# Out:
#     Unnamed: 0                             video_uid  \
# 0            0  77cc4654-4eec-44c6-af05-dbdf71f9a401
# 1           12  f7148e30-2ded-4d14-a8bb-f50813da26df
# 2           20  2cddb76f-24d1-4863-bd91-9a5d1922a543
# 3           29  e3ee87c2-0e48-49cd-93e3-1e39e61a8543
# 4           34  0235dafb-ec68-4177-8aff-e36d6c63742d
# 5           40  a8238ec0-a8d8-4b2e-8d92-d161bb6dcdca
# 6           46  ba01d474-f7dd-48f1-863d-80dcf1a60ea4
# 7           47  e4475271-ea33-4f82-9768-355b226c50ca
# 8           53  a95545b6-8b1e-4d77-a209-c1accf3b057b
# 9           65  f05e4680-0ef5-453e-a096-4f9318df00ae
# 10          71  343f8d57-6331-40f3-823c-2aee4d5cc10f
# 11          78  95673c4c-9c12-4eba-949b-9bd7a29d299d
# 12          80  86ebad37-486c-4687-b50e-67627a4be7a2
# 13          88  f3c90baa-1154-4d30-bdee-f94d1b834f3e
# 14          91  806ebea9-a28f-4429-821c-1e8a753b7ab7
# 15         101  b849a2d6-3eff-4c64-aded-2d706ed1091e
# 16         104  8be6e0c4-a80d-41a3-a1c5-5911ae236990
# ...

# %%
df3 = (data[data['video_source']=='iiith'])
df3
# Out:
#                                 video_uid  \
# 30   6498b686-829f-4e75-9495-78c1e5b4db46
# 33   d623869c-ec8f-4a97-9f97-21d258aa1d77
# 52   50a395ca-e434-46f3-a2f8-67fc4ca3874b
# 58   93f78437-229d-4824-a8c1-68d9b17e754d
# 68   f735d4bb-d65e-4965-ac0d-270c0b9e5993
# 74   a16dde53-8a4d-4246-aab4-9759f0af81f0
# 84   b8952ddf-dd75-4d30-99f2-4e93a286abda
# 110  dfaba491-c7e9-43c0-8294-b5b96d22fa7e
# 111  8762cf76-5526-43a2-b825-a0c396494c87
# 112  106e9447-8a09-4e89-964e-61c927827a56
# 115  6a1bdcdb-0def-4cbb-87ab-0da83b63552c
# 118  ee5ed7ca-667d-4a31-bdc8-13a9b8008246
# 133  057bf03d-b337-475c-82a2-79f0b5b6637f
# 138  a4a3fa0e-778a-4313-a648-b7748605f763
# 167  45a964e8-4eb3-4b41-b9d3-72b949294e27
# 185  10ab80d7-0eb7-4f35-935d-93a9531635d3
# 188  cb235c78-e524-417a-89fd-57b682bb223b
# 197  150c104e-f9bd-4a81-b885-0e8b9968cada
# 210  0e7620e8-f1b5-4093-aff9-d73ab0039e08
# ...

# %%
df5.to_csv('bristol.csv')
df6 =  pd.read_csv('bristol.csv')

# %%
df2["Case"] = "1"  
df2.head()
# Out:
#    Unnamed: 0                             video_uid  \
# 0           0  77cc4654-4eec-44c6-af05-dbdf71f9a401
# 1          12  f7148e30-2ded-4d14-a8bb-f50813da26df
# 2          20  2cddb76f-24d1-4863-bd91-9a5d1922a543
# 3          29  e3ee87c2-0e48-49cd-93e3-1e39e61a8543
# 4          34  0235dafb-ec68-4177-8aff-e36d6c63742d
#
#                                                 path  duration_sec  \
# 0  s3://ego4d-minnesota/public/v1/full_scale/77cc...       1247.13
# 1  s3://ego4d-minnesota/public/v1/full_scale/f714...       1507.70
# 2  s3://ego4d-minnesota/public/v1/full_scale/2cdd...       1884.40
# 3  s3://ego4d-minnesota/public/v1/full_scale/e3ee...       1800.00
# 4  s3://ego4d-minnesota/public/v1/full_scale/0235...         83.77
#
#                                            scenarios split_em split_av  \
# 0  ['Car - commuting, road trip', 'Talking with f...      NaN      NaN
# 1                     ['Car - commuting, road trip']      NaN      NaN
# ...

# %%
df4["Case"] = "2"  
df4.head()
# Out:
#    Unnamed: 0                             video_uid  \
# 0          14  c26cda75-ed47-4f46-9076-25cf75bf9f1d
# 1          18  99723c6d-b508-4484-bfc0-336742d1450d
# 2          24  bd0d69c1-a6e5-4e02-9835-9b9cfcc0c2f6
# 3          49  968139e2-987e-4615-a2d4-fa2e683bae8a
# 4          51  acc20eec-1a35-47f3-8f67-9fa51b7cbd98
#
#                                                 path  duration_sec  \
# 0  s3://ego4d-iiith/public/v1/full_scale/c26cda75...      25417.68
# 1  s3://ego4d-iiith/public/v1/full_scale/99723c6d...       1252.50
# 2  s3://ego4d-iiith/public/v1/full_scale/bd0d69c1...       2643.84
# 3  s3://ego4d-iiith/public/v1/full_scale/968139e2...       3280.75
# 4  s3://ego4d-iiith/public/v1/full_scale/acc20eec...      11638.77
#
#                                        scenarios split_em  split_av split_fho  \
# 0                                 ['Blacksmith']      NaN       NaN     train
# 1                                 ['Blacksmith']      NaN       NaN       NaN
# ...

# %%
df6["Case"]="3"
df6
# Out:
#     Unnamed: 0                             video_uid  \
# 0           25  c48a70f7-44a3-44aa-ac14-baf35e696e5c
# 1           27  2090d1c2-8308-4966-b903-e860b498f4e3
# 2           30  6498b686-829f-4e75-9495-78c1e5b4db46
# 3           33  d623869c-ec8f-4a97-9f97-21d258aa1d77
# 4           52  50a395ca-e434-46f3-a2f8-67fc4ca3874b
# 5           58  93f78437-229d-4824-a8c1-68d9b17e754d
# 6           68  f735d4bb-d65e-4965-ac0d-270c0b9e5993
# 7           74  a16dde53-8a4d-4246-aab4-9759f0af81f0
# 8           84  b8952ddf-dd75-4d30-99f2-4e93a286abda
# 9          110  dfaba491-c7e9-43c0-8294-b5b96d22fa7e
# 10         111  8762cf76-5526-43a2-b825-a0c396494c87
# 11         112  106e9447-8a09-4e89-964e-61c927827a56
# 12         115  6a1bdcdb-0def-4cbb-87ab-0da83b63552c
# 13         118  ee5ed7ca-667d-4a31-bdc8-13a9b8008246
# 14         133  057bf03d-b337-475c-82a2-79f0b5b6637f
# 15         138  a4a3fa0e-778a-4313-a648-b7748605f763
# 16         167  45a964e8-4eb3-4b41-b9d3-72b949294e27
# ...

# %%
df6.to_csv('bristol.csv')
df4.to_csv('iiith.csv')
df2.to_csv("minnesota.csv")

# %%
df7 = pd.concat(
    map(pd.read_csv, ['minnesota.csv', 'iiith.csv','bristol.csv']), ignore_index=True)
print(df7)
# Out:
#      Unnamed: 0  Unnamed: 0.1                             video_uid  \
# 0             0             0  77cc4654-4eec-44c6-af05-dbdf71f9a401
# 1             1            12  f7148e30-2ded-4d14-a8bb-f50813da26df
# 2             2            20  2cddb76f-24d1-4863-bd91-9a5d1922a543
# 3             3            29  e3ee87c2-0e48-49cd-93e3-1e39e61a8543
# 4             4            34  0235dafb-ec68-4177-8aff-e36d6c63742d
# ..          ...           ...                                   ...
# 104          26           235  c0b1b969-46a3-4cb0-b2c9-e7a6928e649e
# 105          27           254  f97b9bb6-9afc-4743-899f-bfe483e88d97
# 106          28           272  f61a6422-1806-43d8-87d6-bc24d9768d9d
# 107          29           273  89193e37-1ed4-4a65-996b-6883f2e1cf61
# 108          30           280  ca8d96b8-56bc-45ae-960a-75b708a40c01
#
#                                                   path  duration_sec  \
# 0    s3://ego4d-minnesota/public/v1/full_scale/77cc...       1247.13
# ...

# %%
merged = df7.to_csv("Casemerged.csv")
merged
